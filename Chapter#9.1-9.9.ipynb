# %%
#EX 9.1

class Resturant():
    def  __init__(self , name , resturant_type):
        self.name = name
        self.resturant_type = resturant_type


    def  describe_res(self):
        print("Resturant name is "+str(self.name.title()))
        print("Cousine "+ str(self.resturant_type.title()))

    def open_resturant(self):
        print(str(self.name.title())+" is open ")




myrest=Resturant('ics','tcs')
myrest.describe_res()
myrest.open_resturant()
# Out:
# Resturant name is Ics
# Cousine Tcs
# Ics is open

# %%
#EX 9.2

class Resturant():
    def  __init__(self , name , resturant_type):
        self.name = name
        self.resturant_type = resturant_type


    def  describe_res(self):
        print("Resturant name is "+str(self.name.title()))
        print("Cousine "+ str(self.resturant_type.title()))

    def open_resturant(self):
        print(str(self.name.title())+" is open ")
3



myrest=Resturant('PC Hotel','All cousines')
myrest2=Resturant('Moven Pick','chinese')
myrest3=Resturant('Marriott Hotel','BABQ')

myrest.describe_res()
myrest.open_resturant()
myrest2.describe_res()
myrest2.open_resturant()
myrest3.describe_res()
myrest3.open_resturant()
# Out:
# Resturant name is Pc Hotel
# Cousine All Cousines
# Pc Hotel is open
# Resturant name is Moven Pick
# Cousine Chinese
# Moven Pick is open
# Resturant name is Marriott Hotel
# Cousine Babq
# Marriott Hotel is open

# %%
#EX9.3
class User():
    def  __init__(self , firstname , lastname):
        self.firstname=firstname
        self.lastname=lastname



    def describe_user(self,age,gender,address):
        print("user information :")
        print("Name :"+self.firstname)
        print("Last Name :" + self.lastname)
        print("age :" +str(age))
        print("Gender :"+gender)
        print("Address :" + address)

    def greet_user(self):
        print("Greetings "+self.firstname+" "+self.lastname)



abc = User('Osama','Imran')
abc.describe_user(24,'Male','Karachi Pakistan')
# Out:
# user information :
# Name :Osama
# Last Name :Imran
# age :24
# Gender :Male
# Address :Karachi Pakistan

# %%
#Ex9.4
class Resturant():
    def  __init__(self , name , resturant_type):
        self.name = name
        self.resturant_type = resturant_type
        self.number_served = 0



    def  describe_res(self):
        print("Resturant name is "+str(self.name.title()))
        print("Cousine "+ str(self.resturant_type.title()))

    def open_resturant(self):
        print(str(self.name.title())+" is open ")

    def set_number_served(self, number_served):

        self.number_served = number_served

    def increment_number_served(self, additional_served):

        self.number_served += additional_served
        print()

restaurant = Resturant('the mean queen', 'pizza')
restaurant.describe_res()

print("\nNumber served: " + str(restaurant.number_served))
restaurant.number_served = 4
print("Number served: " + str(restaurant.number_served))

restaurant.set_number_served(10)
print("Number served: " + str(restaurant.number_served))

restaurant.increment_number_served(80)
print("Number served: " + str(restaurant.number_served))
# Out:
# Resturant name is The Mean Queen
# Cousine Pizza
#
# Number served: 0
# Number served: 4
# Number served: 10
#
# Number served: 90

# %%
#EX9.5
class User():
    def  __init__(self , firstname , lastname):
        self.firstname=firstname
        self.lastname=lastname
        self.login_attempt=0


    def inc_login_attempt(self):
        self.login_attempt+=1

    def reset_login_attempt(self):
        self.login_attempt=0
        print("Reset Login attempt "+str(self.login_attempt))


    def describe_user(self,age,gender,address):
        print("user information :")
        print("Name :"+self.firstname)
        print("Last Name :" + self.lastname)
        print("age :" +str(age))
        print("Gender :"+gender)
        print("Address :" + address)

    def greet_user(self):
        print("Greetings "+self.firstname+" "+self.lastname)



abc = User('Osama','Imran')
abc.describe_user(24,'Male','Karachi Pakistan')
abc.inc_login_attempt()
abc.inc_login_attempt()
abc.inc_login_attempt()
abc.inc_login_attempt()
print("No. of login Attempted "+str(abc.login_attempt))
abc.reset_login_attempt()
abc.greet_user()
# Out:
# user information :
# Name :Osama
# Last Name :Imran
# age :24
# Gender :Male
# Address :Karachi Pakistan
# No. of login Attempted 4
# Reset Login attempt 0
# Greetings Osama Imran

# %%
#Ex9.6

class Resturant():
    def  __init__(self , name , resturant_type):
        self.name = name
        self.resturant_type = resturant_type


    def  describe_res(self):
        print("Resturant name is "+str(self.name.title()))
        print("Cousine "+ str(self.resturant_type.title()))

    def open_resturant(self):
        print(str(self.name.title())+" is open ")



class IceCreamStand(Resturant):

    def __init__(self,name,resturant_type="Icecreams"):
        super().__init__(name,resturant_type)
        self.flavors=[]


    def flavours_display(self):
        for flavour in self.flavors:
            print(flavour)




resturant=IceCreamStand('icecream Parlour')
resturant.flavors=['chocolate','mango','strawberry']
resturant.flavours_display()
resturant.describe_res()
resturant.open_resturant()
# Out:
# chocolate
# mango
# strawberry
# Resturant name is Icecream Parlour
# Cousine Icecreams
# Icecream Parlour is open

# %%
#Ex9.7
class User():
    def  __init__(self , firstname , lastname):
        self.firstname=firstname
        self.lastname=lastname



    def describe_user(self,age,gender,address):
        print("user information :")
        print("Name :"+self.firstname)
        print("Last Name :" + self.lastname)
        print("age :" +str(age))
        print("Gender :"+gender)
        print("Address :" + address)

    def greet_user(self):
        print("Greetings "+self.firstname+" "+self.lastname)



class Admin(User):
    def __init__(self,firstname,lastname):
        super().__init__(firstname,lastname)
        self.privilages=[]


    def show_privilage(self):
        print("Admin can do ")
        for privilage in self.privilages:
            print(privilage)



admin=Admin('osama','imran')
admin.describe_user(24,'Male','Karachi Pakistan')
admin.privilages=['do post','approve post','delete post','banned post']
admin.show_privilage()
# Out:
# user information :
# Name :osama
# Last Name :imran
# age :24
# Gender :Male
# Address :Karachi Pakistan
# Admin can do
# do post
# approve post
# delete post
# banned post

# %%
#EX9.8
class User():
    def  __init__(self , firstname , lastname):
        self.firstname=firstname
        self.lastname=lastname



    def describe_user(self,age,gender,address):
        print("user information :")
        print("Name :"+self.firstname)
        print("Last Name :" + self.lastname)
        print("age :" +str(age))
        print("Gender :"+gender)
        print("Address :" + address)

    def greet_user(self):
        print("Greetings "+self.firstname+" "+self.lastname)



class Admin(User):
    def __init__(self,firstname,lastname):
        super().__init__(firstname,lastname,)
        self.privlages=Privilages()


class Privilages():
    def __init__(self,privilages=[]):
        self.privilages=privilages


    def show_privilage(self):
        print("Privilages are")
        if self.privilages:
            for privilage in self.privilages:
                print(privilage)
        else:
            print("the user has no rights to access")



admin =Admin('osama','imran')
admin.describe_user(33,'Male','karachi')
admin.privlages.show_privilage()
print("Giving Rights .....")

admin.privlages.privilages=['can do post','can change Password','login Account']
admin.privlages.show_privilage()
# Out:
# user information :
# Name :osama
# Last Name :imran
# age :33
# Gender :Male
# Address :karachi
# Privilages are
# the user has no rights to access
# Giving Rights .....
# Privilages are
# can do post
# can change Password
# login Account

# %%
#Ex9.9
class Car():
    """A simple attempt to represent a car."""

    def __init__(self, manufacturer, model, year):
        """Initialize attributes to describe a car."""
        self.manufacturer = manufacturer
        self.model = model
        self.year = year
        self.odometer_reading = 0

    def get_descriptive_name(self):

        long_name = str(self.year) + ' ' + self.manufacturer + ' ' + self.model
        return long_name.title()

    def read_odometer(self):

        print("This car has " + str(self.odometer_reading) + " miles on it.")

    def update_odometer(self, mileage):

        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, miles):

        self.odometer_reading += miles


class Battery():


    def __init__(self, battery_size=60):

        self.battery_size = battery_size

    def describe_battery(self):

        print("This car has a " + str(self.battery_size) + "-kWh battery.")

    def get_range(self):

        if self.battery_size == 60:
            range = 140
        elif self.battery_size == 85:
            range = 185

        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)

    def upgrade_battery(self):

        if self.battery_size == 60:
            self.battery_size = 85
            print("Upgraded the battery to 85 kWh.")
        else:
            print("The battery is already upgraded.")


class ElectricCar(Car):


    def __init__(self, manufacturer, model, year):
        super().__init__(manufacturer, model, year)
        self.battery = Battery()


print("Make an electric car, and check the battery:")
ecar = ElectricCar('tesla', 'model s', 2016)
ecar.battery.describe_battery()

print("\nUpgrade the battery, and check it again:")
ecar.battery.upgrade_battery()
ecar.battery.describe_battery()

print("\nTry upgrading the battery a second time.")
ecar.battery.upgrade_battery()
ecar.battery.describe_battery()
# Out:
# Make an electric car, and check the battery:
# This car has a 60-kWh battery.
#
# Upgrade the battery, and check it again:
# Upgraded the battery to 85 kWh.
# This car has a 85-kWh battery.
#
# Try upgrading the battery a second time.
# The battery is already upgraded.
# This car has a 85-kWh battery.
